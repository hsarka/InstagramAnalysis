# %% [markdown]
# # Text Analysis with Pandas
# We've been __[scraping data with Python](http://github.com/hsarka/instagramScraper)__ for about two weeks and as Senate and Municipal Elections were held during that time, we decided to make a word cloud out of posts' captions.
# <br> Before one can make a word cloud out of scraped data in Tableau, some data wrangling is required. Words need to be tokenized, stripped of special characters, their occurrence counted - stop words excluded - so the output file lines comprise of a word and its occurrence count.
# <br> Our data, scraped with a Python script we wrote earlier, were in a TSV file. This Pandas piece of code reads the TSV file, picks only one - the latest - post instance, strips and splits the post caption and counts the occurance of each word. This list is then exported into an Excel file that could be used for making a Tableau Vizz __[(this word cloud visualization)](https://public.tableau.com/profile/sarka4960#!/vizhome/MunicipalElectionsWordCloud/WordCloud)__.

# %% [markdown]
# This is what the final word cloud looks like:

# %% [markdown]
# <img src="wordcloudInstaCzech.png">

# %% [markdown]
# ***
# ## Importing Pandas
# In this text analysis, Pandas is the only library we will need.

# %%
import pandas as pd

# %% [markdown]
# ## Opening TSV File
# When opening TSV file, Pandas reads it as a CSV with a \t delimiter.
# Also there's no header in our data.

# %%
sourceData = pd.read_csv("dumpedPostData.tsv", delimiter="\t", header = None, encoding = "utf-8")

# %%
sourceData.head()
# Out:
#                             0           1                    2  \
# 0  2018-09-29 14:30:02.217003  choco_afro  1879051365051152095
# 1  2018-09-29 14:30:02.217016  choco_afro  1878496704661368275
# 2  2018-09-29 14:30:02.217062  choco_afro  1878495337804759224
# 3  2018-09-29 14:30:02.217127  choco_afro  1878447225010837769
# 4  2018-09-29 14:30:02.217134  choco_afro  1877008104522273019
#
#                      3                                                  4   5  \
# 0  2018-09-29 11:26:39                 Asistentka Natalie podávající ruku   9
# 1  2018-09-28 17:04:39  Zastupitelé dále volí obecní radu (ta může být...  14
# 2  2018-09-28 17:01:56  Komunální volby #1\nSlíbil jsem shrnout pár zá...   5
# 3  2018-09-28 15:26:20        Fräulein Franke ve svém domovském prostředí  18
# 4  2018-09-26 15:47:04  Studentka z Českých Budějovic na dnešní prohlí...  23
#
#       6
# 0  1935
# 1  1788
# 2  1414
# 3  5644
# 4  3059

# %% [markdown]
# ## Renaming Columns
# Rename the columns to make them more user-friendly.

# %%
sourceData.columns = ["scraping date", "username", "post id", "post date", "post text", "# of comments", "# number of likes"]
sourceData.head()
# Out:
#                 scraping date    username              post id  \
# 0  2018-09-29 14:30:02.217003  choco_afro  1879051365051152095
# 1  2018-09-29 14:30:02.217016  choco_afro  1878496704661368275
# 2  2018-09-29 14:30:02.217062  choco_afro  1878495337804759224
# 3  2018-09-29 14:30:02.217127  choco_afro  1878447225010837769
# 4  2018-09-29 14:30:02.217134  choco_afro  1877008104522273019
#
#              post date                                          post text  \
# 0  2018-09-29 11:26:39                 Asistentka Natalie podávající ruku
# 1  2018-09-28 17:04:39  Zastupitelé dále volí obecní radu (ta může být...
# 2  2018-09-28 17:01:56  Komunální volby #1\nSlíbil jsem shrnout pár zá...
# 3  2018-09-28 15:26:20        Fräulein Franke ve svém domovském prostředí
# 4  2018-09-26 15:47:04  Studentka z Českých Budějovic na dnešní prohlí...
#
#    # of comments  # number of likes
# 0              9               1935
# 1             14               1788
# 2              5               1414
# 3             18               5644
# 4             23               3059

# %% [markdown]
# ## Finding the Newest Post Instance
# ### Ranking
# To find the newest post instance in our data, we used grouping by _username_ and _post id_ as those are the unique identificators. We rank them descendingly by _scraping date_.

# %%
sourceData["rank"] = sourceData.groupby(by = ["username", "post id"])["scraping date"].transform(lambda x: x.rank(ascending = False))

# %% [markdown]
# Checking the assigned rank for a single post.

# %%
sourceData.loc[sourceData["post id"] == 1879051365051152095]
# Out:
#                     scraping date    username              post id  \
# 0      2018-09-29 14:30:02.217003  choco_afro  1879051365051152095
# 621    2018-09-29 15:30:02.761334  choco_afro  1879051365051152095
# 1241   2018-09-29 16:30:02.150157  choco_afro  1879051365051152095
# 1861   2018-09-29 17:30:02.251014  choco_afro  1879051365051152095
# 2481   2018-09-29 18:30:02.603931  choco_afro  1879051365051152095
# 3101   2018-09-29 19:30:01.751798  choco_afro  1879051365051152095
# 3721   2018-09-29 20:30:02.174725  choco_afro  1879051365051152095
# 4341   2018-09-29 21:30:02.017911  choco_afro  1879051365051152095
# 4961   2018-09-29 22:30:01.894221  choco_afro  1879051365051152095
# 5426   2018-09-29 23:30:02.066758  choco_afro  1879051365051152095
# 6034   2018-09-30 00:30:02.624012  choco_afro  1879051365051152095
# 6654   2018-09-30 01:30:02.219539  choco_afro  1879051365051152095
# 7274   2018-09-30 02:30:02.116648  choco_afro  1879051365051152095
# 7894   2018-09-30 03:30:02.340000  choco_afro  1879051365051152095
# 8514   2018-09-30 04:30:02.417277  choco_afro  1879051365051152095
# 9134   2018-09-30 05:30:02.492791  choco_afro  1879051365051152095
# 9754   2018-09-30 06:30:01.910935  choco_afro  1879051365051152095
# 10374  2018-09-30 07:30:02.527254  choco_afro  1879051365051152095
# 10994  2018-09-30 08:30:02.173571  choco_afro  1879051365051152095
# 11614  2018-09-30 09:00:02.894300  choco_afro  1879051365051152095
# 12234  2018-09-30 10:00:02.315237  choco_afro  1879051365051152095
# 12854  2018-09-30 11:00:02.374869  choco_afro  1879051365051152095
# 13474  2018-09-30 12:00:02.025673  choco_afro  1879051365051152095
# 14094  2018-09-30 13:00:02.012959  choco_afro  1879051365051152095
# 14702  2018-09-30 14:00:02.014663  choco_afro  1879051365051152095
# 15322  2018-09-30 15:00:02.379099  choco_afro  1879051365051152095
# 15930  2018-09-30 16:00:02.440356  choco_afro  1879051365051152095
# 16550  2018-09-30 17:00:02.570639  choco_afro  1879051365051152095
# 17158  2018-09-30 18:00:02.687692  choco_afro  1879051365051152095
# 17778  2018-09-30 19:00:02.094328  choco_afro  1879051365051152095
# ...                           ...         ...                  ...
# 51655  2018-10-03 02:00:01.827204  choco_afro  1879051365051152095
# 52275  2018-10-03 03:00:02.161042  choco_afro  1879051365051152095
# 52895  2018-10-03 04:00:01.781081  choco_afro  1879051365051152095
# 53515  2018-10-03 05:00:02.179945  choco_afro  1879051365051152095
# 54135  2018-10-03 06:00:02.860617  choco_afro  1879051365051152095
# 54755  2018-10-03 07:00:03.115345  choco_afro  1879051365051152095
# 55363  2018-10-03 09:00:02.538626  choco_afro  1879051365051152095
# 55983  2018-10-03 10:00:02.621894  choco_afro  1879051365051152095
# 56603  2018-10-03 11:00:02.036063  choco_afro  1879051365051152095
# 57223  2018-10-03 12:00:02.281642  choco_afro  1879051365051152095
# 57843  2018-10-03 13:00:02.091810  choco_afro  1879051365051152095
# 58463  2018-10-03 14:00:02.580966  choco_afro  1879051365051152095
# 59083  2018-10-03 15:00:02.570401  choco_afro  1879051365051152095
# 59703  2018-10-03 16:00:01.827422  choco_afro  1879051365051152095
# 60314  2018-10-03 17:00:01.799749  choco_afro  1879051365051152095
# 60934  2018-10-03 18:00:02.183616  choco_afro  1879051365051152095
# 61532  2018-10-03 19:00:03.039364  choco_afro  1879051365051152095
# 62152  2018-10-03 20:00:02.721131  choco_afro  1879051365051152095
# 62772  2018-10-03 21:00:02.383034  choco_afro  1879051365051152095
# 63380  2018-10-03 22:00:02.622378  choco_afro  1879051365051152095
# 64000  2018-10-03 23:00:01.856366  choco_afro  1879051365051152095
# 64620  2018-10-04 00:00:02.313387  choco_afro  1879051365051152095
# 65240  2018-10-04 01:00:02.358488  choco_afro  1879051365051152095
# 65860  2018-10-04 02:00:02.494565  choco_afro  1879051365051152095
# 66480  2018-10-04 03:00:01.921725  choco_afro  1879051365051152095
# 67100  2018-10-04 04:00:02.087140  choco_afro  1879051365051152095
# 67720  2018-10-04 05:00:02.215539  choco_afro  1879051365051152095
# 68340  2018-10-04 06:00:02.031690  choco_afro  1879051365051152095
# 68948  2018-10-04 07:00:01.967706  choco_afro  1879051365051152095
# 69568  2018-10-04 08:00:02.262571  choco_afro  1879051365051152095
#
#                  post date                           post text  # of comments  \
# 0      2018-09-29 11:26:39  Asistentka Natalie podávající ruku              9
# 621    2018-09-29 11:26:39  Asistentka Natalie podávající ruku             11
# 1241   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             13
# 1861   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             14
# 2481   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             14
# 3101   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             14
# 3721   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             14
# 4341   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             15
# 4961   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             15
# 5426   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             15
# 6034   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             15
# 6654   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 7274   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 7894   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 8514   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 9134   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 9754   2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 10374  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 10994  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 11614  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 12234  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 12854  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 13474  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 14094  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 14702  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 15322  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 15930  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 16550  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 17158  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 17778  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# ...                    ...                                 ...            ...
# 51655  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 52275  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 52895  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 53515  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 54135  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 54755  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 55363  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 55983  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 56603  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 57223  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 57843  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 58463  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 59083  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 59703  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 60314  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 60934  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 61532  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 62152  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 62772  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 63380  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 64000  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 64620  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 65240  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 65860  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 66480  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 67100  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 67720  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 68340  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 68948  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
# 69568  2018-09-29 11:26:39  Asistentka Natalie podávající ruku             16
#
#        # number of likes   rank
# 0                   1935  113.0
# 621                 2115  112.0
# 1241                2252  111.0
# 1861                2367  110.0
# 2481                2458  109.0
# 3101                2543  108.0
# 3721                2612  107.0
# 4341                2663  106.0
# 4961                2709  105.0
# 5426                2727  104.0
# 6034                2736  103.0
# 6654                2742  102.0
# 7274                2747  101.0
# 7894                2751  100.0
# 8514                2756   99.0
# 9134                2769   98.0
# 9754                2802   97.0
# 10374               2839   96.0
# 10994               2868   95.0
# 11614               2884   94.0
# 12234               2911   93.0
# 12854               2929   92.0
# 13474               2951   91.0
# 14094               2961   90.0
# 14702               2971   89.0
# 15322               3004   88.0
# 15930               3019   87.0
# 16550               3037   86.0
# 17158               3073   85.0
# 17778               3106   84.0
# ...                  ...    ...
# 51655               3260   30.0
# 52275               3260   29.0
# 52895               3260   28.0
# 53515               3260   27.0
# 54135               3261   26.0
# 54755               3261   25.0
# 55363               3261   24.0
# 55983               3262   23.0
# 56603               3262   22.0
# 57223               3262   21.0
# 57843               3262   20.0
# 58463               3262   19.0
# 59083               3263   18.0
# 59703               3263   17.0
# 60314               3263   16.0
# 60934               3264   15.0
# 61532               3264   14.0
# 62152               3265   13.0
# 62772               3265   12.0
# 63380               3265   11.0
# 64000               3265   10.0
# 64620               3265    9.0
# 65240               3265    8.0
# 65860               3265    7.0
# 66480               3265    6.0
# 67100               3265    5.0
# 67720               3265    4.0
# 68340               3265    3.0
# 68948               3265    2.0
# 69568               3265    1.0
#
# [113 rows x 8 columns]

# %% [markdown]
# ### The Newest Instance
# We picked just the post ranked as # 1 to have the newest instance.

# %%
cleanData = sourceData.loc[sourceData["rank"] == 1]

# %%
cleanData.head()
# Out:
#                    scraping date          username              post id  \
# 11    2018-09-29 14:30:02.217224        choco_afro  1874675251562179159
# 143   2018-09-29 14:30:08.431512            ods.cz  1871017608742297509
# 535   2018-09-29 14:30:31.021692  alenaschillerova  1868839511421899772
# 643   2018-09-29 15:30:03.222565          tomio.cz  1874913619066496354
# 2407  2018-09-29 17:30:31.306534         strakovka  1820375570215909100
#
#                 post date                                          post text  \
# 11    2018-09-23 10:32:06  Přesně před 80 lety byla vyhlášena všeobecná m...
# 143   2018-09-18 09:25:01             Skvělá atmosféra v Olomouci. Děkujeme!
# 535   2018-09-15 09:17:32                                 Dny NATO v Ostravě
# 643   2018-09-23 18:25:42  Sto korun za hodinu – hnutí STAN „demokratů“ F...
# 2407  2018-07-10 12:28:20  Poslední červnový den – Francie – Elysejský pa...
#
#       # of comments  # number of likes  rank
# 11               30               2832   1.0
# 143               0                132   1.0
# 535               0                 31   1.0
# 643              11                123   1.0
# 2407              1                 36   1.0

# %% [markdown]
# ## Data Cleansing
# ### New Data Frame for Text Analysis
# To strip and split the text, we prepared a new DF with two columns - _original_ text and _clean_ text that will later contain a list of words.

# %%
newDataset = pd.DataFrame(cleanData['post text'])
newData = pd.concat([newDataset["post text"], newDataset["post text"]], axis=1, keys=['original', 'clean'])
newData.head()
# Out:
#                                                original  \
# 11    Přesně před 80 lety byla vyhlášena všeobecná m...
# 143              Skvělá atmosféra v Olomouci. Děkujeme!
# 535                                  Dny NATO v Ostravě
# 643   Sto korun za hodinu – hnutí STAN „demokratů“ F...
# 2407  Poslední červnový den – Francie – Elysejský pa...
#
#                                                   clean
# 11    Přesně před 80 lety byla vyhlášena všeobecná m...
# 143              Skvělá atmosféra v Olomouci. Děkujeme!
# 535                                  Dny NATO v Ostravě
# 643   Sto korun za hodinu – hnutí STAN „demokratů“ F...
# 2407  Poslední červnový den – Francie – Elysejský pa...

# %% [markdown]
# ## Spliting with Regex
# We split the words to a list by regex \W_ that includes characters a-z, A-Z, 0-9 and an underscore.

# %%
newData['clean'] = newData.clean.str.strip().str.split('[\W_]+')
newData.head()
# Out:
#                                                original  \
# 11    Přesně před 80 lety byla vyhlášena všeobecná m...
# 143              Skvělá atmosféra v Olomouci. Děkujeme!
# 535                                  Dny NATO v Ostravě
# 643   Sto korun za hodinu – hnutí STAN „demokratů“ F...
# 2407  Poslední červnový den – Francie – Elysejský pa...
#
#                                                   clean
# 11    [Přesně, před, 80, lety, byla, vyhlášena, všeo...
# 143        [Skvělá, atmosféra, v, Olomouci, Děkujeme, ]
# 535                             [Dny, NATO, v, Ostravě]
# 643   [Sto, korun, za, hodinu, hnutí, STAN, demokrat...
# 2407  [Poslední, červnový, den, Francie, Elysejský, ...

# %% [markdown]
# ## Pivoting List Items
# Pivots the list to a word-per-line format.

# %%
rows = list()
for row in newData[['original', 'clean']].iterrows():
    r = row[1]
    for clean in r.clean:
        rows.append((r.original, clean))

clean = pd.DataFrame(rows, columns=['original', 'clean'])
clean.head(10)
# Out:
#                                             original       clean
# 0  Přesně před 80 lety byla vyhlášena všeobecná m...      Přesně
# 1  Přesně před 80 lety byla vyhlášena všeobecná m...        před
# 2  Přesně před 80 lety byla vyhlášena všeobecná m...          80
# 3  Přesně před 80 lety byla vyhlášena všeobecná m...        lety
# 4  Přesně před 80 lety byla vyhlášena všeobecná m...        byla
# 5  Přesně před 80 lety byla vyhlášena všeobecná m...   vyhlášena
# 6  Přesně před 80 lety byla vyhlášena všeobecná m...   všeobecná
# 7  Přesně před 80 lety byla vyhlášena všeobecná m...  mobilizace
# 8  Přesně před 80 lety byla vyhlášena všeobecná m...
# 9             Skvělá atmosféra v Olomouci. Děkujeme!      Skvělá

# %% [markdown]
# ## Getting Rid of Empty Strings
# As we have some empty strings - remnants after splitting - we just filter these out.

# %%
clean = clean[clean.clean.str.len() > 0]
clean.head(10)
# Out:
#                                              original       clean
# 0   Přesně před 80 lety byla vyhlášena všeobecná m...      Přesně
# 1   Přesně před 80 lety byla vyhlášena všeobecná m...        před
# 2   Přesně před 80 lety byla vyhlášena všeobecná m...          80
# 3   Přesně před 80 lety byla vyhlášena všeobecná m...        lety
# 4   Přesně před 80 lety byla vyhlášena všeobecná m...        byla
# 5   Přesně před 80 lety byla vyhlášena všeobecná m...   vyhlášena
# 6   Přesně před 80 lety byla vyhlášena všeobecná m...   všeobecná
# 7   Přesně před 80 lety byla vyhlášena všeobecná m...  mobilizace
# 9              Skvělá atmosféra v Olomouci. Děkujeme!      Skvělá
# 10             Skvělá atmosféra v Olomouci. Děkujeme!   atmosféra

# %% [markdown]
# ## Lowercasing
# Lots of people play with upper/lowercase even on Instagram. For us from the meaning perspective, they are the same, so we decided to lowercase everything. (We'll deal with names manually afterwards.)

# %%
clean['clean'] = clean.clean.str.lower()
clean.head()
#clean.loc[clean["clean"]=="000"]
#df.loc[df['shield'] > 6]
# Out:
#                                             original   clean
# 0  Přesně před 80 lety byla vyhlášena všeobecná m...  přesně
# 1  Přesně před 80 lety byla vyhlášena všeobecná m...    před
# 2  Přesně před 80 lety byla vyhlášena všeobecná m...      80
# 3  Přesně před 80 lety byla vyhlášena všeobecná m...    lety
# 4  Přesně před 80 lety byla vyhlášena všeobecná m...    byla

# %% [markdown]
# ## Counting
# Here we count each word's occurance and reset the dataframe's index. The _word_ column will be used for stop-word lookup later.

# %%
counts = clean.clean.value_counts().to_frame()
counts = counts.reset_index()
counts.columns = ['word', 'occurance']
counts.head()
# Out:
#   word  occurance
# 0    a        951
# 1    v        677
# 2   na        613
# 3   se        514
# 4   je        335

# %% [markdown]
# ## Stop words
# For English stop words, you can use __[(library from NLTK)](https://www.nltk.org)__.
# <br> As we're analysing Czech language, we use our own CSV file containing stop words.

# %%
stop = pd.read_csv("stopwordsCzech.csv", header = None, encoding = "utf-8")
stop.columns = ["stopword"]
stop.head()
# Out:
#   stopword
# 0        a
# 1      aby
# 2   ačkoli
# 3       aj
# 4      ale

# %% [markdown]
# To compare the _word_ column and 'stopwords_czech.csv' file, we use __.isin()__. To exclude words that are stop-words, we use __.dropna()__.
# <br>TBD: We took the top 500 words for manual polishing afterwards.  with consideration of grammatical declension and conjugation.

# %%
countsStripped = counts[~counts["word"].isin(stop["stopword"])].dropna()
toExport = countsStripped.head(500)
toExport.head()
# Out:
#      word  occurance
# 22    spd         98
# 25  czech         79
# 26  volby         78
# 33  praha         66
# 37   2018         59

# %% [markdown]
# ## Export to Excel
# As Tableau works nicely with Excel files, we decided to export into this format.

# %%
toExport.to_excel('wordcloudPrep.xlsx', sheet_name='words')
